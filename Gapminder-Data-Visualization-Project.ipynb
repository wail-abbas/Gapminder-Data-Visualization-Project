# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import imageio
sns.set()

# %% [markdown]
# # Reading Data Files

# %%
life_exp = pd.read_excel('../data/gapminder_lifeexpectancy.xlsx', index_col=0)
continents = pd.read_csv('../data/continents.csv', sep=';', index_col=0)
population = pd.read_excel('../data/gapminder_population.xlsx', index_col=0)
fertility = pd.read_csv('../data/gapminder_total_fertility.csv', index_col=0)

# %%
life_exp.head(3)
# Out:
#                         1800  1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.2  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
#
# [3 rows x 217 columns]

# %%
continents.head(3)
# Out:
#            country
# continent
# Africa     Algeria
# Africa      Angola
# Africa       Benin

# %%
population.head(3)
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                        ...        2006        2007        2008        2009  \
# Total population       ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# ...

# %%
fertility.head(3)
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan             7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan             7.0  ...   6.7  6.46   6.2  5.93  5.66   5.4  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan             4.9  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
#
# [3 rows x 216 columns]

# %% [markdown]
# # Dealing with NaN Values

# %%
life_exp.dropna(inplace=True)

# %%
life_exp.head(3)
# Out:
#                   1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Afghanistan      28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Albania          35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria          28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                   1808   1809  ...  2007  2008  2009  2010  2011  2012  2013  \
# Life expectancy                ...
# Afghanistan      28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8
# Albania          35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7
# Algeria          28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3
#
#                  2014  2015   2016
# Life expectancy
# Afghanistan      54.9  53.8  52.72
# Albania          77.9  78.0  78.10
# Algeria          76.3  76.4  76.50
#
# [3 rows x 217 columns]

# %%
continents.dropna(inplace=True)

# %%
continents.head(3)
# Out:
#            country
# continent
# Africa     Algeria
# Africa      Angola
# Africa       Benin

# %%
population.dropna(inplace=True)

# %%
population.head(3)
# Out:
#                        1800       1810       1820       1830       1840  \
# Total population
# Afghanistan       3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Albania            410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria           2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                        1850       1860       1870       1880       1890  ...  \
# Total population                                                         ...
# Afghanistan       3810047.0  3973968.0  4169690.0  4419695.0  4710171.0  ...
# Albania            506889.0   552800.0   610036.0   672544.0   741688.0  ...
# Algeria           3299305.0  3536468.0  3811028.0  4143163.0  4525691.0  ...
#
#                         2006        2007        2008        2009        2010  \
# Total population
# Afghanistan       25183615.0  25877544.0  26528741.0  27207291.0  27962207.0
# Albania            3050741.0   3010849.0   2968026.0   2929886.0   2901883.0
# ...

# %%
fertility.dropna(inplace=True)

# %%
fertility.head(3)
# Out:
#                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Afghanistan           7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Albania               4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria               6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                       1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate        ...
# Afghanistan           7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Albania               4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria               6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
#                       2013  2014  2015
# Total fertility rate
# Afghanistan           4.90  4.68  4.47
# Albania               1.77  1.78  1.78
# Algeria               2.80  2.76  2.71
#
# [3 rows x 216 columns]

# %% [markdown]
# # Reading Table's Columns

# %%
fertility.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life_exp.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
population.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %% [markdown]
# # Converting fertility table to be an integer

# %%
fertility.columns = fertility.columns.astype(int)

# %%
fertility.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %% [markdown]
# # Checking the row index of each Table:

# %%
fertility.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        ...
#        'Uzbekistan', 'Vanuatu', 'Venezuela', 'West Bank and Gaza',
#        'Western Sahara', 'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Total fertility rate', length=199)

# %%
life_exp.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        ...
#        'Vanuatu', 'Venezuela', 'West Bank and Gaza', 'Western Sahara',
#        'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia', 'Zimbabwe',
#        'South Sudan'],
#       dtype='object', name='Life expectancy', length=201)

# %%
population.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Venezuela', 'West Bank and Gaza', 'Western Sahara',
#        'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia', 'Zimbabwe',
#        'South Sudan'],
#       dtype='object', name='Total population', length=229)

# %%
continents.index
# Out:
# Index(['Africa', 'Africa', 'Africa', 'Africa', 'Africa', 'Africa', 'Africa',
#        'Africa', 'Africa', 'Africa',
#        ...
#        'South America', 'South America', 'South America', 'South America',
#        'South America', 'South America', 'South America', 'South America',
#        'South America', 'South America'],
#       dtype='object', name='continent', length=194)

# %% [markdown]
# # Changing the name of the index to be called country

# %%
fertility.index.name = 'country'

# %%
fertility.head(2)
# Out:
#              1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  ...  \
# country                                                                  ...
# Afghanistan   7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0  ...
# Albania       4.6   4.6   4.6   4.6   4.6   4.6   4.6   4.6   4.6   4.6  ...
#
#              2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# country
# Afghanistan  6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# Albania      1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
#
# [2 rows x 216 columns]

# %%
population.index.name = 'country'

# %%
population.head(2)
# Out:
#                   1800       1810       1820       1830       1840       1850  \
# country
# Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0  3625022.0  3810047.0
# Albania       410445.0   423591.0   438671.0   457234.0   478227.0   506889.0
#
#                   1860       1870       1880       1890  ...        2006  \
# country                                                  ...
# Afghanistan  3973968.0  4169690.0  4419695.0  4710171.0  ...  25183615.0
# Albania       552800.0   610036.0   672544.0   741688.0  ...   3050741.0
#
#                    2007        2008        2009        2010        2011  \
# country
# Afghanistan  25877544.0  26528741.0  27207291.0  27962207.0  28809167.0
# Albania       3010849.0   2968026.0   2929886.0   2901883.0   2886010.0
#
#                    2012        2013        2014        2015
# country
# Afghanistan  29726803.0  30682500.0  31627506.0  32526562.0
# Albania       2880667.0   2883281.0   2889676.0   2896679.0
#
# ...

# %%
life_exp.index.name = 'country'

# %%
life_exp.head(2)
# Out:
#               1800  1801   1802   1803   1804   1805   1806   1807   1808  \
# country
# Afghanistan  28.21  28.2  28.19  28.18  28.17  28.16  28.15  28.14  28.13
# Albania      35.40  35.4  35.40  35.40  35.40  35.40  35.40  35.40  35.40
#
#               1809  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# country             ...
# Afghanistan  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# Albania      35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
#
#               2016
# country
# Afghanistan  52.72
# Albania      78.10
#
# [2 rows x 217 columns]

# %% [markdown]
# # Converting the tables into long format

# %%
fertility = fertility.reset_index()

# %%
fertility = fertility.melt(id_vars='country', var_name='year', value_name='fertility_rate')

# %%
fertility.head(5)
# Out:
#                country  year  fertility_rate
# 0          Afghanistan  1800            7.00
# 1              Albania  1800            4.60
# 2              Algeria  1800            6.99
# 3               Angola  1800            6.93
# 4  Antigua and Barbuda  1800            5.00

# %%
population = population.reset_index()

# %%
population = population.melt(id_vars='country', var_name='year', value_name='population')

# %%
population.head(5)
# Out:
#           country  year  population
# 0     Afghanistan  1800   3280000.0
# 1         Albania  1800    410445.0
# 2         Algeria  1800   2503218.0
# 3  American Samoa  1800      8170.0
# 4         Andorra  1800      2654.0

# %%
life_exp = life_exp.reset_index()

# %%
life_exp = life_exp.melt(id_vars='country', var_name='year', value_name='life_expectancy')

# %%
life_exp.head(5)
# Out:
#                country  year  life_expectancy
# 0          Afghanistan  1800            28.21
# 1              Albania  1800            35.40
# 2              Algeria  1800            28.82
# 3               Angola  1800            26.98
# 4  Antigua and Barbuda  1800            33.54

# %%
continents = continents.reset_index()

# %%
continents.head(5)
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %% [markdown]
# # Merging tables

# %%
fert_life = fertility.merge(life_exp)

# %%
fert_life
# Out:
#                      country  year  fertility_rate  life_expectancy
# 0                Afghanistan  1800            7.00            28.21
# 1                    Albania  1800            4.60            35.40
# 2                    Algeria  1800            6.99            28.82
# 3                     Angola  1800            6.93            26.98
# 4        Antigua and Barbuda  1800            5.00            33.54
# ...                      ...   ...             ...              ...
# 42763                Vietnam  2015            1.70            75.40
# 42764  Virgin Islands (U.S.)  2015            2.45            80.60
# 42765                  Yemen  2015            3.83            66.00
# 42766                 Zambia  2015            5.59            56.70
# 42767               Zimbabwe  2015            3.35            59.30
#
# [42768 rows x 4 columns]

# %%
cont_pop = continents.merge(population)

# %%
cont_pop
# Out:
#            continent    country  year  population
# 0             Africa    Algeria  1800   2503218.0
# 1             Africa    Algeria  1810   2595056.0
# 2             Africa    Algeria  1820   2713079.0
# 3             Africa    Algeria  1830   2880355.0
# 4             Africa    Algeria  1840   3082721.0
# ...              ...        ...   ...         ...
# 14251  South America  Venezuela  2011  29427631.0
# 14252  South America  Venezuela  2012  29854238.0
# 14253  South America  Venezuela  2013  30276045.0
# 14254  South America  Venezuela  2014  30693827.0
# 14255  South America  Venezuela  2015  31108083.0
#
# [14256 rows x 4 columns]

# %%
df = cont_pop.merge(fert_life)

# %%
df
# Out:
#            continent    country  year  population  fertility_rate  \
# 0             Africa    Algeria  1800   2503218.0            6.99
# 1             Africa    Algeria  1810   2595056.0            6.99
# 2             Africa    Algeria  1820   2713079.0            6.99
# 3             Africa    Algeria  1830   2880355.0            6.99
# 4             Africa    Algeria  1840   3082721.0            6.99
# ...              ...        ...   ...         ...             ...
# 13441  South America  Venezuela  2011  29427631.0            2.44
# 13442  South America  Venezuela  2012  29854238.0            2.42
# 13443  South America  Venezuela  2013  30276045.0            2.39
# 13444  South America  Venezuela  2014  30693827.0            2.36
# 13445  South America  Venezuela  2015  31108083.0            2.34
#
#        life_expectancy
# 0                28.82
# 1                28.82
# 2                28.82
# 3                28.82
# 4                28.82
# ...                ...
# ...

# %% [markdown]
# # Creating Animated Scatterplot

# %%
df_year = df['year'] == 1960
plt.figure(figsize=(12, 8))
sns.scatterplot(x='life_expectancy', y='fertility_rate', data=df[df_year], sizes=(50,5500), size=(df[df_year]['population']), hue='country', legend=None)
plt.axis((0, 90, 0, 10))
plt.xlabel('Life Expectancy')
plt.ylabel('Fertility')
# Out:
# Text(0, 0.5, 'Fertility')

# %%
years_range = df['year'].isin(range(1960, 2016))
for year in df[years_range]['year'].unique():
    years = df['year'] == year
    plt.figure(figsize=(12, 8))
    sns.scatterplot(x='life_expectancy',
                    y='fertility_rate',
                    data=df_subset[years],
                    sizes=(50,5500),
                    size=(df[years]['population']),
                    hue='country',
                    legend=None)
    plt.axis((0, 90, 0, 10))
    plt.title(str(year))
    plt.xlabel('Life Expectancy [Years]')
    plt.ylabel('Fertility')
    plt.savefig(f'plots/lifeexp_{year}.png')
    plt.close()

# %%
images = []

for i in range(1960, 2016):
    filename = 'plots/lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('lifeexp.gif', images, fps=20)
